# %%
import pandas as pd, matplotlib.pyplot as plt, numpy as np
# %matplotlib inline

# %%
accidents = pd.read_csv("accidents_2017.csv")

# %%
new_cols = [col.replace(" ", "_").lower() for col in accidents.columns]
accidents.columns = new_cols
accidents.head()
# accidents.info() # information about the dataframe

# accidents.isnull().sum().any() # returns True if there is at least one null in the dataframe.
# Out:
#                 id district_name           neighborhood_name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               street   weekday      month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    day  hour part_of_the_day  mild_injuries  serious_injuries  victims  \
# 0   13     8         Morning              2                 0        2
# ...

# %%
len(accidents)
# Out:
# 10339

# %%
accidents.groupby(["part_of_the_day", "weekday"]).count()
# Out:
#                             id  district_name  neighborhood_name  street  \
# part_of_the_day weekday
# Afternoon       Friday     884            884                884     884
#                 Monday     742            742                742     742
#                 Saturday   556            556                556     556
#                 Sunday     419            419                419     419
#                 Thursday   843            843                843     843
#                 Tuesday    815            815                815     815
#                 Wednesday  823            823                823     823
# Morning         Friday     707            707                707     707
#                 Monday     630            630                630     630
#                 Saturday   359            359                359     359
#                 Sunday     284            284                284     284
# ...

# %%
accidents.describe()
# Out:
#                 day          hour  mild_injuries  serious_injuries  \
# count  10339.000000  10339.000000   10339.000000      10339.000000
# mean      15.775994     13.811394       1.154174          0.023310
# std        8.763455      5.316490       0.742294          0.163803
# min        1.000000      0.000000       0.000000          0.000000
# 25%        8.000000     10.000000       1.000000          0.000000
# 50%       16.000000     14.000000       1.000000          0.000000
# 75%       23.000000     18.000000       1.000000          0.000000
# max       31.000000     23.000000      10.000000          4.000000
#
#             victims  vehicles_involved     longitude      latitude
# count  10339.000000       10339.000000  10339.000000  10339.000000
# mean       1.178644           1.920979      2.162832     41.399346
# std        0.735145           0.714011      0.024176      0.021251
# min        0.000000           0.000000      2.091855     41.323094
# ...

# %%
accidents[accidents.vehicles_involved == 14] # accidents with 0 vehicles involved
# Out:
#                    id district_name       neighborhood_name  \
# 6937  2017S001886          Eixample  la Dreta de l'Eixample
#
#                                                  street    weekday  month  \
# 6937  ARAGÓ                                         ...  Wednesday  March
#
#       day  hour part_of_the_day  mild_injuries  serious_injuries  victims  \
# 6937    8     3           Night              0                 0        0
#
#       vehicles_involved  longitude   latitude
# 6937                 14   2.162429  41.390124

# %%
accidents.groupby(["weekday"]).size().plot.barh()

# %%
accidents.groupby(["part_of_the_day"]).size().plot.barh()

# %%
accidents.groupby(["month"]).size().plot.barh()

# %%
plt.scatter(s=np.repeat(.5, len(accidents)), x=accidents["latitude"], y=accidents["longitude"])
plt.scatter(s=np.repeat(1, len(total_victims)), x=total_victims["latitude"], y=total_victims["longitude"], color="red")

accidents[["victims"]].describe()
# Out:
#             victims
# count  10339.000000
# mean       1.178644
# std        0.735145
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       10.000000

# %%
total_victims = accidents[["latitude", "longitude", "victims"]]
total_victims = total_victims[accidents.victims > 2]

accidents["victims"].hist()

# %%
accidents[accidents["victims"] >= 50]
# Out:
# Empty DataFrame
# Columns: [id, district_name, neighborhood_name, street, weekday, month, day, hour, part_of_the_day, mild_injuries, serious_injuries, victims, vehicles_involved, longitude, latitude]
# Index: []

# %%
accidents["victims"].max()
# Out:
# 10
